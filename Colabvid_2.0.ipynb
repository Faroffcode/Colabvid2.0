# %% [markdown]
# # 🎬 Colabvid 2.0
#
# Set up and run the Colabvid Telegram video-processing bot.
#
# 🧪 This notebook uses the `upload-speed-test` branch.
#
# ⚠️ Do not share your API hash or bot token.

# %%
# !git clone -b upload-speed-test https://github.com/Faroffcode/Colabvid2.0.git
# %cd Colabvid2.0
# !apt-get update -qq
# !apt-get install -y -qq ffmpeg
# !ffmpeg -version
# !pip install -r requirements.txt

# %% [markdown]
# ## 🔐 Configure credentials
#
# Run this cell and enter your Telegram API credentials when prompted. The setup must run in the current Colab session so the environment variables remain available to the bot.

# %%
# %run colab_setup.py

# %% [markdown]
# ## ▶️ Start the bot
#
# Run the next cell after completing the environment setup.

# %%
# !python app.py
